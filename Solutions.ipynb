# %% [markdown]
# # Lab | Cleaning numerical data

# %% [markdown]
# For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pandas as pd

# %% [markdown]
# ### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv') 
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ### 3. First look at its main features (head, shape, info).

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# ### 4. Rename the columns so they follow the PE8 (snake case).

# %%
customer_df.columns = customer_df.columns.str.replace(' ', '_').str.lower()

# %% [markdown]
# ### 5. Change effective to date column to datetime format.

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], infer_datetime_format=True)

# %%
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# ### 6. Check NaN values per column.

# %%
customer_df.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# ### 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
customer_df_num = customer_df._get_numeric_data()
customer_df_num
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# Empirical hint to differentiate continuous from discrete variables : Continuous variables are generally float whereas discrete variables are generally integer. It is not always true though.
# But in this dataframe, it works. So I go with the below solution.
# Dear TA, if you have a better solution, please feel free to share it please. Thanks.

# %%
def diff_variables(df):
    categorical = df.select_dtypes('object')
    continuous = df.select_dtypes('float64')
    discrete = df.select_dtypes('int64')
    return categorical, continuous, discrete

# %%
diff_variables(customer_df)
# Out:
# (     customer       state response  coverage education employmentstatus  \
#  0     BU79786  Washington       No     Basic  Bachelor         Employed
#  1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
#  2     AI49188      Nevada       No   Premium  Bachelor         Employed
#  3     WW63253  California       No     Basic  Bachelor       Unemployed
#  4     HB64268  Washington       No     Basic  Bachelor         Employed
#  ...       ...         ...      ...       ...       ...              ...
#  9129  LA72316  California       No     Basic  Bachelor         Employed
#  9130  PK87824  California      Yes  Extended   College         Employed
#  9131  TD14365  California       No  Extended  Bachelor       Unemployed
#  9132  UP19263  California       No  Extended   College         Employed
#  9133  Y167826  California       No  Extended   College       Unemployed
#
#       gender location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# ### 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
customer_df_cat = customer_df.select_dtypes('object')

# %%
for col in customer_df_cat.select_dtypes('object'):
    print (customer_df_cat[col].nunique(), '\n')
    print(customer_df_cat[col].value_counts(), '\n')
    
# df.nunique(axis=0) 
# , '\n' -> mise en page du résultat : espace entre les colonnes
# Out:
# 9134
#
# RE32481    1
# QV89018    1
# BR44176    1
# FF28650    1
# KA58700    1
#           ..
# ZG10765    1
# JO13576    1
# BH43020    1
# TV77808    1
# CX99919    1
# Name: customer, Length: 9134, dtype: int64
#
# 5
#
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# 2
#
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# 3
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# 5
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# 5
#
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#
# 2
#
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# 3
#
# Suburban    5779
# Rural       1773
# ...

# %% [markdown]
# All categorical datas seem clear. So I would not do any cleaning without more information on the operations we would need to do on the datas.

# %% [markdown]
# ### 9. Get categorical features.

# %%
customer_df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer          9134 non-null   object
#  1   state             9134 non-null   object
#  2   response          9134 non-null   object
#  3   coverage          9134 non-null   object
#  4   education         9134 non-null   object
#  5   employmentstatus  9134 non-null   object
#  6   gender            9134 non-null   object
#  7   location_code     9134 non-null   object
#  8   marital_status    9134 non-null   object
#  9   policy_type       9134 non-null   object
#  10  policy            9134 non-null   object
#  11  renew_offer_type  9134 non-null   object
#  12  sales_channel     9134 non-null   object
#  13  vehicle_class     9134 non-null   object
#  14  vehicle_size      9134 non-null   object
# dtypes: object(15)
# memory usage: 1.0+ MB

# %% [markdown]
# ### 10. What should we do with the customer_id column?

# %% [markdown]
# Different soutions can be applied when we have an "ID_column" in a dataframe.
# Sometimes, the ID_column can be set as an index for the dataframe.
# Sometimes, the ID_column can bring some information that we can use.
# However, sometimes, the ID_column cannot help us or to organize our datas neither to get relevant information.
# In this case, one can decide to drop the column to get cleaner dataframe.
#
# In this case, we are in the third case and we should drop this column as it does not bring any relevant information to analyse our datas.

# %%
customer_df = customer_df.drop(['customer], axis=1)
